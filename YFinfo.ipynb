# %%
# Imports
# import os
# import requests
# import pandas as pd
# from MCForecastTools import MCSimulation
# import panel as pn
# pn.extension('plotly')
# import plotly.express as px
# import hvplot.pandas
# import matplotlib.pyplot as plt
# from pathlib import Path
# from dotenv import load_dotenv
import yfinance as yf
# import numpy as np
# from itertools import product
# %matplotlib inline

## Reinstall commands if having trouble with json, pyvizenv resintall guide
# pip install alpaca_trade_api
# pip install yfinance
# Git Bash and Jupyter Terminal: pip install numpy==1.19.4 --user

# %%
msft = yf.Ticker("MSFT")
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. Its Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. Its Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also offers support services and Microsoft consulting services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. Its More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; Windows Internet of Things; and MSN advertising. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. It sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. It has collaborations with Dynatrace, Inc., Morgan Stanley, Micro Focus, WPP plc, ACI Worldwide, Inc., and iCIMS, Inc., as well as strategic relationships with Avaya Holdings Corp. and wejo Limited. Microsoft Corporation was founded in 1975 and is based in Redmond, Washington.',
#  'city': 'Redmond',
#  'phone': '425 882 8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'industry': 'Software—Infrastructure',
#  'ebitdaMargins': 0.48648998,
#  'profitMargins': 0.38515,
#  'grossMargins': 0.68864995,
#  'operatingCashflow': 81945001984,
#  'revenueGrowth': 0.22,
#  'operatingMargins': 0.42143002,
#  'ebitda': 85745000448,
#  'targetLowPrice': 299.93,
#  'recommendationKey': 'buy',
#  'grossProfits': 115856000000,
#  'freeCashflow': 49819750400,
#  'targetMedianPrice': 360,
#  'currentPrice': 336.06,
#  'earningsGrowth': 0.489,
#  'currentRatio': 2.165,
#  'returnOnAssets': 0.14589,
#  'numberOfAnalystOpinions': 38,
#  'targetMeanPrice': 357.27,
#  'debtToEquity': 51.938,
#  'returnOnEquity': 0.49303,
#  'targetHighPrice': 407,
#  'totalCash': 130584002560,
#  'totalDebt': 78934999040,
#  'totalRevenue': 176250994688,
#  'totalCashPerShare': 17.393,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 23.395,
#  'quickRatio': 1.961,
#  'recommendationMean': 1.6,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 14.023,
#  'beta3Year': None,
#  'enterpriseToEbitda': 28.824,
#  '52WeekChange': 0.5388067,
#  'morningStarRiskRating': None,
#  'forwardEps': 10.51,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7507979776,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 20.242,
#  'sharesShort': 48556022,
#  'sharesPercentSharesOut': 0.0064999997,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1625011200,
#  'heldPercentInstitutions': 0.71957,
#  'netIncomeToCommon': 67882999808,
#  'trailingEps': 8.939,
#  'lastDividendValue': 0.56,
#  'SandP52WeekChange': 0.3230616,
#  'priceToBook': 16.602114,
#  'heldPercentInsiders': 0.00079,
#  'nextFiscalYearEnd': 1688083200,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': 1.86,
#  'sharesShortPreviousMonthDate': 1631664000,
#  'floatShares': 7500247224,
#  'beta': 0.862337,
#  'enterpriseValue': 2471482884096,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1629244800,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.476,
#  'priceToSalesTrailing12Months': 14.315559,
#  'dateShortInterest': 1634256000,
#  'pegRatio': 2.23,
#  'ytdReturn': None,
#  'forwardPE': 31.97526,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0064999997,
#  'sharesShortPriorMonth': 44204519,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 336.44,
#  'regularMarketOpen': 338.51,
#  'twoHundredDayAverage': 281.22992,
#  'trailingAnnualDividendYield': 0.006836286,
#  'payoutRatio': 0.25059998,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 338.78,
#  'navPrice': None,
#  'averageDailyVolume10Day': 26094200,
#  'regularMarketPreviousClose': 336.44,
#  'fiftyDayAverage': 304.95972,
#  'trailingAnnualDividendRate': 2.3,
#  'open': 338.51,
#  'toCurrency': None,
#  'averageVolume10days': 26094200,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.48,
#  'exDividendDate': 1637107200,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 334.4217,
#  'currency': 'USD',
#  'trailingPE': 37.594807,
#  'regularMarketVolume': 22570098,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2523131543552,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 23459634,
#  'dayLow': 334.4217,
#  'ask': 335.88,
#  'askSize': 1300,
#  'volume': 22570098,
#  'fiftyTwoWeekHigh': 338.79,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.45,
#  'fiftyTwoWeekLow': 208.16,
#  'bid': 335.62,
#  'tradeable': False,
#  'dividendYield': 0.0074,
#  'bidSize': 1200,
#  'dayHigh': 338.78,
#  'regularMarketPrice': 336.06,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com'}

# %%
arkk = yf.Ticker("ARKK")
arkk.info
# Out:
# {'exchange': 'PCX',
#  'shortName': 'ARK Innovation ETF',
#  'longName': 'ARK Innovation ETF',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'ETF',
#  'symbol': 'ARKK',
#  'messageBoardId': 'finmb_268203659',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': 1.56,
#  'profitMargins': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'fundInceptionDate': 1414627200,
#  'annualReportExpenseRatio': None,
#  'totalAssets': 25520136192,
#  'bookValue': None,
#  'fundFamily': 'ARK ETF Trust',
#  'lastFiscalYearEnd': None,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': None,
#  'nextFiscalYearEnd': None,
#  'yield': 0,
#  'mostRecentQuarter': None,
#  'enterpriseValue': None,
#  'priceHint': 2,
#  'threeYearAverageReturn': 0.425,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': 'Exchange Traded Fund',
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': None,
#  'pegRatio': None,
#  'ytdReturn': None,
#  'forwardPE': None,
#  'maxAge': 1,
#  'lastCapGain': None,
#  'category': 'Mid-Cap Growth',
#  'fiveYearAverageReturn': 0.4734,
#  'phone': '855-406-1506',
#  'longBusinessSummary': 'The investment seeks long-term growth of capital.\n The fund is an actively-managed exchange-traded fund ("ETF") that will invest under normal circumstances primarily (at least 65% of its assets) in domestic and foreign equity securities of companies that are relevant to the fund&#39;s investment theme of disruptive innovation. Its investments in foreign equity securities will be in both developed and emerging markets. It may invest in foreign securities (including investments in American Depositary Receipts ("ADRs") and Global Depositary Receipts ("GDRs")) and securities listed on local foreign exchanges. The fund is non-diversified.',
#  'companyOfficers': [],
#  'previousClose': 124.39,
#  'regularMarketOpen': 123.96,
#  'twoHundredDayAverage': 117.80022,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 124.501,
#  'navPrice': 121.73,
#  'averageDailyVolume10Day': 5301857,
#  'regularMarketPreviousClose': 124.39,
#  'fiftyDayAverage': 116.618286,
#  'trailingAnnualDividendRate': None,
#  'open': 123.96,
#  'toCurrency': None,
#  'averageVolume10days': 5301857,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 121.02,
#  'currency': 'USD',
#  'regularMarketVolume': 5807110,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 5383876,
#  'dayLow': 121.02,
#  'ask': 122,
#  'askSize': 800,
#  'volume': 5807110,
#  'fiftyTwoWeekHigh': 159.7,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 91.8,
#  'bid': 121.83,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 1000,
#  'dayHigh': 124.501,
#  'regularMarketPrice': 122.29,
#  'logo_url': ''}

# %%
coin = yf.Ticker("COIN")
coin.info
# Out:
# {'zip': '19801',
#  'sector': 'Technology',
#  'fullTimeEmployees': 2176,
#  'longBusinessSummary': 'Coinbase Global, Inc. provides financial infrastructure and technology for the cryptoeconomy. It offers the primary financial account in the cryptoeconomy for retail users; a marketplace with a pool of liquidity for transacting in crypto assets for institutions; and technology and services that enable ecosystem partners to build crypto-based applications and securely accept crypto assets as payment. The company was founded in 2012 and is based in Wilmington, Delaware.',
#  'city': 'Wilmington',
#  'state': 'DE',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.coinbase.com',
#  'maxAge': 1,
#  'address1': '1209 Orange Street',
#  'industry': 'Software—Application',
#  'ebitdaMargins': 0.62176,
#  'profitMargins': 0.53486,
#  'grossMargins': 1,
#  'operatingCashflow': 9761095680,
#  'revenueGrowth': 10.974,
#  'operatingMargins': 0.61362,
#  'ebitda': 3064154880,
#  'targetLowPrice': 250,
#  'recommendationKey': 'buy',
#  'grossProfits': 1274855000,
#  'freeCashflow': 1855531136,
#  'targetMedianPrice': 371.5,
#  'currentPrice': 337.05,
#  'earningsGrowth': 12.335,
#  'currentRatio': 1.471,
#  'returnOnAssets': 0.20145,
#  'numberOfAnalystOpinions': 20,
#  'targetMeanPrice': 382.65,
#  'debtToEquity': 40.817,
#  'returnOnEquity': 0.91346,
#  'targetHighPrice': 600,
#  'totalCash': 4386195968,
#  'totalDebt': 1887143040,
#  'totalRevenue': 4928198144,
#  'totalCashPerShare': 20.795,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 46.327,
#  'quickRatio': 0.507,
#  'recommendationMean': 2.1,
#  'exchange': 'NMS',
#  'shortName': 'Coinbase Global, Inc.',
#  'longName': 'Coinbase Global, Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'COIN',
#  'messageBoardId': 'finmb_377154867',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 13.919,
#  'beta3Year': None,
#  'enterpriseToEbitda': 22.386,
#  '52WeekChange': 0.02671504,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.34,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 141790000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 22.029,
#  'sharesShort': 5230311,
#  'sharesPercentSharesOut': 0.0248,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.31293,
#  'netIncomeToCommon': 1775351040,
#  'trailingEps': 13.578,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.3230616,
#  'priceToBook': 15.300286,
#  'heldPercentInsiders': 0.01846,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1625011200,
#  'shortRatio': 1.46,
#  'sharesShortPreviousMonthDate': 1631664000,
#  'floatShares': 134138151,
#  'beta': None,
#  'enterpriseValue': 68594544640,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 48.794,
#  'priceToSalesTrailing12Months': 17.911901,
#  'dateShortInterest': 1634256000,
#  'pegRatio': 0.41,
#  'ytdReturn': None,
#  'forwardPE': 53.162457,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 4504080,
#  'impliedSharesOutstanding': 261900000,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 344.45,
#  'regularMarketOpen': 345.23,
#  'twoHundredDayAverage': 256.6645,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 345.23,
#  'navPrice': None,
#  'averageDailyVolume10Day': 5185900,
#  'regularMarketPreviousClose': 344.45,
#  'fiftyDayAverage': 275.65344,
#  'trailingAnnualDividendRate': None,
#  'open': 345.23,
#  'toCurrency': None,
#  'averageVolume10days': 5185900,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 333.442,
#  'currency': 'USD',
#  'trailingPE': 24.823242,
#  'regularMarketVolume': 3527615,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 88273395712,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 4838960,
#  'dayLow': 333.442,
#  'ask': 338.6,
#  'askSize': 900,
#  'volume': 3527615,
#  'fiftyTwoWeekHigh': 429.54,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 208,
#  'bid': 337.5,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 900,
#  'dayHigh': 345.23,
#  'regularMarketPrice': 337.05,
#  'logo_url': 'https://logo.clearbit.com/coinbase.com'}

# %%
btc = yf.Ticker("BTC-USD")
btc.info
# Out:
# {'companyOfficers': [],
#  'name': 'Bitcoin',
#  'startDate': 1367107200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency . Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 18,866,381. The last known price of Bitcoin is 61,966.35741002 USD and is up 2.65 over the last 24 hours. It is currently trading on 8291 active market(s) with $26,244,014,637.27 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 1,
#  'exchange': 'CCC',
#  'shortName': 'Bitcoin USD',
#  'exchangeTimezoneName': 'Europe/London',
#  'exchangeTimezoneShortName': 'GMT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '0',
#  'quoteType': 'CRYPTOCURRENCY',
#  'symbol': 'BTC-USD',
#  'messageBoardId': 'finmb_BTC_CCC',
#  'market': 'ccc_market',
#  'previousClose': 61528.2,
#  'regularMarketOpen': 61528.2,
#  'twoHundredDayAverage': 45378.215,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': 24902524928,
#  'regularMarketDayHigh': 62475.156,
#  'navPrice': None,
#  'averageDailyVolume10Day': 34885095712,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 61528.2,
#  'fiftyDayAverage': 54630.27,
#  'trailingAnnualDividendRate': None,
#  'open': 61528.2,
#  'toCurrency': 'USD=X',
#  'averageVolume10days': 34885095712,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': 18866624,
#  'regularMarketDayLow': 61432.49,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 24902524928,
#  'lastMarket': 'CoinMarketCap',
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1178263093248,
#  'volumeAllCurrencies': 24902524928,
#  'strikePrice': None,
#  'averageVolume': 35814913147,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 61432.49,
#  'ask': None,
#  'ytdReturn': None,
#  'askSize': None,
#  'volume': 24902524928,
#  'fiftyTwoWeekHigh': 66930.39,
#  'forwardPE': None,
#  'fromCurrency': 'BTC',
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 14744.11,
#  'bid': None,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': None,
#  'dayHigh': 62475.156,
#  'regularMarketPrice': 62452.246,
#  'logo_url': ''}

# %%
QETH = yf.Ticker("QETH-U.TO")
QETH.info
# Out:
# {'zip': 'M5H 1A1',
#  'sector': '',
#  'city': 'Toronto',
#  'state': 'ON',
#  'country': 'Canada',
#  'companyOfficers': [],
#  'maxAge': 1,
#  'address1': '4800-One King Street West',
#  'industry': '',
#  'ebitdaMargins': 0,
#  'profitMargins': 0,
#  'grossMargins': 0,
#  'operatingCashflow': None,
#  'revenueGrowth': None,
#  'operatingMargins': 0,
#  'ebitda': None,
#  'targetLowPrice': None,
#  'recommendationKey': 'none',
#  'grossProfits': None,
#  'freeCashflow': None,
#  'targetMedianPrice': None,
#  'currentPrice': 75.54,
#  'earningsGrowth': None,
#  'currentRatio': None,
#  'returnOnAssets': None,
#  'numberOfAnalystOpinions': None,
#  'targetMeanPrice': None,
#  'debtToEquity': None,
#  'returnOnEquity': None,
#  'targetHighPrice': None,
#  'totalCash': None,
#  'totalDebt': None,
#  'totalRevenue': None,
#  'totalCashPerShare': None,
#  'financialCurrency': None,
#  'revenuePerShare': None,
#  'quickRatio': None,
#  'recommendationMean': None,
#  'exchange': 'TOR',
#  'longName': 'The Ether Fund',
#  'exchangeTimezoneName': 'America/Toronto',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'QETH-U.TO',
#  'messageBoardId': 'finmb_678872477',
#  'market': 'ca_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': None,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': None,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': None,
#  'heldPercentInstitutions': 0.19733,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.3230616,
#  'priceToBook': None,
#  'heldPercentInsiders': 0.00014,
#  'nextFiscalYearEnd': None,
#  'yield': None,
#  'mostRecentQuarter': None,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': None,
#  'beta': None,
#  'enterpriseValue': None,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': None,
#  'dateShortInterest': None,
#  'pegRatio': None,
#  'ytdReturn': None,
#  'forwardPE': None,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 75.95,
#  'regularMarketOpen': 75.73,
#  'twoHundredDayAverage': None,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 76.05,
#  'navPrice': None,
#  'averageDailyVolume10Day': None,
#  'regularMarketPreviousClose': 75.95,
#  'fiftyDayAverage': None,
#  'trailingAnnualDividendRate': None,
#  'open': 75.73,
#  'toCurrency': None,
#  'averageVolume10days': None,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 74.54,
#  'currency': 'USD',
#  'regularMarketVolume': 22127,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': None,
#  'dayLow': 74.54,
#  'ask': 75.52,
#  'askSize': None,
#  'volume': 22127,
#  'fiftyTwoWeekHigh': 76.05,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 74.54,
#  'bid': 75.17,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': None,
#  'dayHigh': 76.05,
#  'regularMarketPrice': 75.54,
#  'logo_url': ''}
